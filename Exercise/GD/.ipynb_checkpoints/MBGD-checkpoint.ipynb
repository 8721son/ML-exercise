# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.rand(100)
y = 0.3*x + 0.8

# %%
def plot_prediction(pred,y):
    plt.plot(x,y)
    plt.plot(x,pred)
    plt.show()

# %%
w = np.random.uniform(-1.0,1.0)
bias = np.random.uniform(-1.0,1.0)

num_epoch=100
learning_rate=0.7
cnt = 0
for epoch in range(num_epoch):
    batch_size = 10
    batch_count = 100/10
    start = 0
    end = 10
    for iteration in range(int(batch_count)):
    
        x_batch = x[start: end]
        y_batch = 0.3*x_batch + 0.8
        
        start += 10
        end += 10

        predict_batch = w*x_batch + bias
      
        w = w - 2*learning_rate*((predict_batch - y_batch)*x_batch).mean()
        bias = bias - 2*learning_rate * (predict_batch - y_batch).mean()

        predict = w*x+ bias
        error = ((y - predict)**2).mean()
        if error < 0.00001:
            break
            
        cnt += 1
        if iteration==0 :    
            plot_prediction(predict,y)
            print("cnt= ",cnt,"iteration= ", iteration,"w= ", w, "bias= ", bias, "error= ", error)
# Out:
# cnt=  1 iteration=  0 w=  0.974192197995889 bias=  0.986791155166356 error=  0.300098667343697
# cnt=  11 iteration=  0 w=  0.43743013457388646 bias=  0.8031382258155371 error=  0.006413507670588364
# cnt=  21 iteration=  0 w=  0.33635022183186153 bias=  0.7970383827837688 error=  0.00032425869225641925
# cnt=  31 iteration=  0 w=  0.31051927931366835 bias=  0.7988258168919803 error=  2.4591821247685737e-05

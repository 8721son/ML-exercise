# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.rand(100)
y= 0.2 * x + 0.5

# %%
def plot_prediction(pred,y):
    plt.plot(x,y)
    plt.plot(x,pred)
    plt.show()

# %% [markdown]
# ## Gradient Descent 구현

# %% [markdown]
# - 업데이트할 W : Learning Rate * ((Y예측-Y실제)*X)평균
# - 업데이트할 b : Learning Rate * ((Y예측-Y실제)*1)평균

# %%
w = np.random.uniform(-1,1)
b = np.random.uniform(-1,1)

learning_rate = 0.7
cnt = 0
for epoch in range(1000):
    y_pred = w * x + b
    error = np.abs(y_pred - y).mean()
    if error < 0.001 :
        break
        
    w_grad = learning_rate * ((y_pred-y)*x).mean()
    b_grad = learning_rate * (y_pred-y).mean()
     
    w = w - w_grad
    b = b - b_grad
    cnt += 1
    if epoch % 10 == 0:
        y_pred = w * x + b
        plot_prediction(y_pred,y)
        print("cnt= ",cnt,"iteration= ", epoch,"w= ", w, "bias= ", b, "error= ", error)
# Out:
# cnt=  1 iteration=  0 w=  0.5888861987451857 bias=  0.31424686446961914 error=  0.2692103077036418
# cnt=  11 iteration=  10 w=  0.44313765506755687 bias=  0.3659187657264159 error=  0.061681968068386286
# cnt=  21 iteration=  20 w=  0.35691072408272784 bias=  0.4134696616598298 error=  0.03980692447353663
# cnt=  31 iteration=  30 w=  0.30126352220288427 bias=  0.4441569918885013 error=  0.025689699692732656
# cnt=  41 iteration=  40 w=  0.26535117971622946 bias=  0.46396129248123796 error=  0.016579041938834693
# cnt=  51 iteration=  50 w=  0.2421748779560155 bias=  0.4767421476108584 error=  0.010699410070854008
# cnt=  61 iteration=  60 w=  0.22721787637695964 bias=  0.484990369105954 error=  0.006904945188427385
# cnt=  71 iteration=  70 w=  0.2175652623166819 bias=  0.4903134212133584 error=  0.004456158586263154
# cnt=  81 iteration=  80 w=  0.2113358748485987 bias=  0.49374869313894754 error=  0.002875815637060741
# cnt=  91 iteration=  90 w=  0.20731569254511234 bias=  0.4959656718505264 error=  0.001855929365677812
# cnt=  101 iteration=  100 w=  0.20472123749859747 bias=  0.4973964158248193 error=  0.0011977380489890143

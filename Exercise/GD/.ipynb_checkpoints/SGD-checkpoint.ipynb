# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.rand(100)
y = 0.3*x + 0.8
print(x)
# Out:
# [0.92476916 0.35780043 0.5151843  0.3968084  0.36473534 0.09890823
#  0.6416141  0.13109326 0.17898497 0.09295239 0.71022838 0.00872455
#  0.56563249 0.88118407 0.29706165 0.32121612 0.23371785 0.61525126
#  0.81369185 0.59236312 0.0620526  0.02690315 0.93428992 0.43195628
#  0.22604821 0.93879829 0.35972954 0.2604075  0.51432501 0.69887477
#  0.67377529 0.69597164 0.66731737 0.15454465 0.7368778  0.88781565
#  0.78228535 0.13944571 0.95641734 0.77827184 0.95838532 0.35735954
#  0.88138632 0.49976976 0.29631944 0.30435486 0.26550561 0.57636316
#  0.44611034 0.24721427 0.42949763 0.78345595 0.31096544 0.59472791
#  0.04062574 0.26228361 0.84705673 0.60607967 0.81517876 0.42815875
#  0.0896462  0.12272182 0.95106671 0.60085772 0.95209835 0.03305279
#  0.5772128  0.26849934 0.22525008 0.38807156 0.11151684 0.56686188
#  0.42387638 0.35272506 0.35224649 0.66310258 0.15539259 0.20911519
#  0.3735284  0.18212455 0.99799231 0.03039009 0.32921125 0.60512885
#  0.64744528 0.43330172 0.11925751 0.25406075 0.98743708 0.6826114
#  0.74482197 0.3025506  0.84220221 0.5488764  0.93500804 0.4651359
#  0.6267511  0.27848443 0.00558724 0.42921254]

# %%
def plot_prediction(pred,y):
    plt.plot(x,y)
    plt.plot(x,pred)
    plt.show()

# %%
w = np.random.uniform(-1.0,1.0)
bias = np.random.uniform(-1.0,1.0)

num_epoch=1000
learning_rate=0.5
cnt =0
for epoch in range(num_epoch):
    
    x_sgd = np.random.choice(x)
    y_sgd = 0.3*x_sgd + 0.8
    
    predict_sgd = w * x_sgd + bias
    
    w = w - 2*learning_rate*((predict_sgd - y_sgd)*x_sgd)
    bias = bias - 2*learning_rate * (predict_sgd - y_sgd)
    
    predict = w * x + bias
    error = ((y - predict)**2).mean()
    cnt += 1
    if epoch%10 == 0:
        predict = w*x + bias
        plot_prediction(predict,y)
        print("cnt=", cnt ,"epoch= ", epoch,"w= ", w, "bias= ", bias, "error= ", error)
        
    if error < 0.000001:
        break
# Out:
# cnt= 1 epoch=  0 w=  0.3383321191622978 bias=  0.8978824796594509 error=  0.013592425126687506
# cnt= 11 epoch=  10 w=  0.29559978640684664 bias=  0.8169137568294198 error=  0.00022130394942251265
# cnt= 21 epoch=  20 w=  0.28999754524339283 bias=  0.8038061580908589 error=  8.854562133958397e-06
# cnt= 31 epoch=  30 w=  0.2962900478168623 bias=  0.8003624637425449 error=  3.053300749399971e-06
